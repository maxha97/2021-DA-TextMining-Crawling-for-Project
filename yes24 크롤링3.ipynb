# %%
import numpy as np
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementNotInteractableException
import time
import re

# %% [markdown]
# ### 리스트 생성
# - 새로 데이터 객체 생성을 위해 실행 필요
# - 만약 기존 리스트에다 계속 이어서 데이터 쌓을꺼면 추가로 실행하지 말것

# %%
book_titles = list()
book_abstract = list()

# %% [markdown]
# ### 연도 및 월 설정
# - 크롤릴할 연도와 크롤링을 시작할 월 설정
# - 만약 2021년 3월 입력시, 2021년 3월부터 12월에 대한 데이터 수집

# %%
year = 2021
month = 1
n = 1

# %% [markdown]
# ### 자기 계발서 크롤링

# %%
for month in list(range(month, 13)):
    url = 'http://www.yes24.com/24/category/bestseller?CategoryNumber=001001026&sumgb=09&year=' + str(year) + '&month=' + str(month).zfill(2) + '&FetchSize=200'
    print('*************  년도: ' + str(year) + ' 월: ' + str(month) +'  ****************')
    driver = webdriver.Chrome()
    driver.get(url)
    driver.implicitly_wait(3)
    driver.find_element_by_css_selector('#divYes24SCMEvent > div.yPopBot > div.pTxt > label').click()

    for m in list(range(n-1,200)):    
        driver.implicitly_wait(3)
        map = '#category_layout > tbody > tr:nth-child(' + str(m*2+1) + ') > td.goodsTxtInfo > p:nth-child(1) > a:nth-child(1)'
        title = (driver.find_element_by_css_selector(map)).text
        if title not in book_titles:
            print(m+1,title)
            yes = driver.find_element_by_css_selector(map).click()
            driver.implicitly_wait(3)
            book_titles.append(title)
            try:
                abstract1 = (driver.find_element_by_css_selector('#infoset_introduce > div.infoSetCont_wrap > table')).text
            except NoSuchElementException:
                try:
                    abstract1 = (driver.find_element_by_css_selector('#infoset_introduce > div.infoSetCont_wrap > div.infoWrap_txt')).text
                except NoSuchElementException:
                    pass
            try:
                abstract2 = (driver.find_element_by_css_selector('#infoset_toc > div.infoSetCont_wrap > div.infoWrap_txt')).text
            except NoSuchElementException:
                try:
                    abstract2 = '' #단원목록이 없는 경우에 해당
                except NoSuchElementException:
                    pass
            book_abstract.append(abstract1 + abstract2 )
#             print(abstract1 + abstract2)
            driver.back()
        else:
            pass
    driver.close()
# Out:
# *************  년도: 2021 월: 1  ****************
# 1 나의 하루는 4시 30분에 시작된다
# 2 5년 후 나에게 Q&A a day (2021 메모리아 화이트 Gift Edition)
# 3 더 해빙 The Having (40만부 기념 리커버 에디션)
# 4 다산의 마지막 습관
# 5 기분이 태도가 되지 않게 (10만 부 기념 봄 에디션)
# 6 데일 카네기 인간관계론
# 7 하버드 상위 1퍼센트의 비밀
# 8 0430 TIME TO PLAN : 일어나라, 삶이 바뀐다
# 9 멘탈의 연금술
# 10 성숙한 어른이 갖춰야 할 좋은 심리 습관
# 11 타이탄의 도구들 (리커버 에디션)
# 12 김미경의 리부트
# 13 아주 작은 습관의 힘
# 14 습관의 디테일
# 15 폴리매스
# 16 한 번이라도 모든 걸 걸어본 적 있는가
# 17 자존감 수업
# 18 오은영의 화해
# 19 알면서도 알지 못하는 것들 (YES24 스페셜 에디션)
# 20 라이브 커머스 성공 전략
# 21 미라클 모닝
# 22 마음이 무기가 될 때
# 23 말의 결
# 24 그림의 힘 (리커버 에디션)
# 25 나를 사랑하는 연습
# 26 어웨이크
# 27 빨강 머리 앤이 5년 후 나에게 : Q & A a day
# 28 지금, 인생의 체력을 길러야 할 때
# 29 AI 최강의 수업
# 30 관계에도 연습이 필요합니다
# 31 프레임
# 32 말센스
# 33 슬로싱킹
# 34 다산의 마지막 공부
# 35 보도 섀퍼의 돈
# 36 문해력 공부
# 37 말 그릇 (벚꽃 에디션)
# 38 실무에 바로 쓰는 일잘러의 보고서 작성법
# 39 운의 그릇
# 40 시작의 기술
# 41 그릿 Grit : 100쇄 기념 리커버 에디션
# 42 나는 왜 네 말이 힘들까
# 43 말투 하나 바꿨을 뿐인데 (리커버 에디션)
# 44 설득의 심리학 1
# 45 [예스리커버] 에이트
# 46 변호사세요? 유튜버세요?
# 47 가면과 본색
# 48 신경 끄기의 기술
# 49 생각의 비밀
# 50 하버드 100년 전통 말하기 수업 (리커버 에디션)
# 51 생각정리 스킬
# 52 뜨겁게 나를 응원한다
# 53 에이트 : 씽크
# 54 90일 챌린지
# 55 마인드셋
# 56 오래된 비밀
# 57 50부터, 운을 내 편으로 만드는 좋은 습관
# 58 체인저블 CHANGEABLE
# 59 끌리는 말투에는 비밀이 있다
# 60 말의 품격
# 61 나는 무조건 합격하는 공부만 한다
# 62 백만장자 시크릿
# 63 하루 5분 아침 일기
# 64 타인의 속마음, 심리학자들의 명언 700
# 65 위대한 나의 발견 강점혁명
# 66 다꿈 플래너 vol. 2
# 67 거울명상
# 68 해빙 노트 Having Note
# 69 일 잘하는 사람은 단순하게 말합니다
# 70 [예스리커버] 타인의 해석
# 71 백만장자 메신저
# 72 어른의 습관
# 73 데일 카네기 인간관계론 & 자기관리론
# 74 나를 잃어가면서 지켜야 할 관계는 없다
# 75 이건희의 말
# 76 해빗 HABIT (스페셜 에디션)
# 77 Do it! 첫 코딩 with 자바
# 78 The Secret 시크릿
# 79 어린 왕자 5년 후 나에게 : Q&A a day
# 80 파이어족의 재테크
# 81 욕망의 진화
# 82 50부터는 인생관을 바꿔야 산다
# 83 성공하는 사람들의 7가지 습관
# 84 심리학이 이렇게 나를 변화시킬 줄이야
# 85 내가 예민한 게 아니라 네가 너무한 거야
# 86 부자의 말센스
# 87 오십부터는 우아하게 살아야 한다
# 88 아티스트 웨이
# 89 STICK 스틱!
# 90 나는 4시간만 일한다
# 91 닥터 도티의 삶을 바꾸는 마술가게
# 92 더 시스템 THE SYSTEM
# 93 생각정리 스피치
# 94 하버드 새벽 4시 반 (리커버 에디션)
# 95 더 플러스
# 96 모두에게 사랑받을 필요는 없다
# 97 심리학을 만나 행복해졌다
# 98 어떻게 살아야 할지 막막한 너에게
# 99 파리에서 도시락을 파는 여자
# 100 서른다섯, 출근하기 싫어졌습니다
# 101 리딩으로 리드하라
# 102 조셉 머피 잠재의식의 힘
# 103 뇌는 팩트에 끌리지 않는다
# 104 끌리는 단어 혹하는 문장
# 105 통찰과 역설
# 106 나는 오늘도 아무렇지 않은 척합니다
# 107 눈치
# 108 주식회사 랩추종윤
# 109 말습관을 바꾸니 인정받기 시작했다
# 110 1만 시간의 재발견
# 111 남들이 나를 함부로 하지 못하게 하라
# 112 바쁨 중독
# 113 내가 처음 뇌를 열었을 때
# 114 될 일은 된다
# 115 빨강 머리 앤이 3년 후 나에게 : Q & A a day
# 116 시간 낭비를 확 줄여주는 초효율 공부법
# 117 피터 드러커 자기경영노트
# 118 절제의 성공학
# 119 왓칭 Watching
# 120 횡설수설하지 않고 정확하게 설명하는 법
# 121 당신도 초자연적이 될 수 있다
# 122 운, 준비하는 미래
# 123 생각하라! 그러면 부자가 되리라
# 124 저, 죄송한데 무슨 말인지 모르겠어요
# 125 일 잘하는 사람은 단순하게 합니다
# 126 원씽 THE ONE THING
# 127 완벽한 공부법
# 128 운의 힘
# 129 나를 믿고 일한다는 것
# 130 사람은 어떻게 생각하고 배우고 기억하는가
# 131 이지성의 꿈꾸는 다락방
# 132 일을 잘 맡긴다는 것
# 133 리얼리티 트랜서핑 1
# 134 모든 것은 태도에서 결정된다
# 135 어린 왕자 3년 후 나에게 : Q&A a day
# 136 지금 하지 않으면 언제 하겠는가
# 137 모든 관계는 말투에서 시작된다
# 138 1년 안에 AI 빅데이터 전문가가 되는 법
# 139 화성에서 온 남자 금성에서 온 여자 (100만 부 기념 리커버 에디션)
# 140 내가 춤추면 코끼리도 춤춘다
# 141 당신의 삶에 명상이 필요할 때
# 142 하루 10분 나를 생각해
# 143 기획자의 습관
# 144 엄마의 20년
# 145 기브 앤 테이크
# 146 린치핀
# 147 혼자 잘해주고 상처받지 마라
# 148 생각 정리 습관
# 149 초집중
# 150 그림의 힘 2
# 151 몰입 합본판 (100쇄 기념 합본 에디션)
# 152 적을 만들지 않는 대화법
# 153 생각정리 기획력
# 154 도쿄R부동산 이렇게 일 합니다
# 155 공부, 이래도 안되면 포기하세요
# 156 무기가 되는 스토리
# 157 사람을 얻는 지혜
# 158 행복한 이기주의자
# 159 권력의 법칙
# 160 10대, 인생을 바꾸는 진로 수업
# 161 누가 내 치즈를 옮겼을까?
# 162 영어책 한 권 외워봤니?
# 163 습관이 답이다
# 164 움직임의 힘
# 165 취업 끝판왕 옴스에게 배우는 스펙을 뛰어넘는 자소서
# 166 회복탄력성
# 167 이익을 내는 사장은 말투가 다르다
# 168 후배 하나 잘 키웠을 뿐인데
# 169 THE ONE PAGE PROPOSAL
# 170 혼자 있는 시간의 힘
# 171 안티프래질 Antifragile
# 172 오늘 나에게 정말 필요했던 말
# 173 어떻게 원하는 것을 얻는가 밀리언 특별판
# 174 선물 (스페셜 에디션)
# 175 감사하면 달라지는 것들
# 176 취업 끝판왕 옴스에게 배우는 스펙을 뛰어넘는 면접의 기술
# 177 150년 하버드 글쓰기 비법
# 178 이 한마디가 나를 살렸다
# 179 미러
# 180 리얼리티 트랜서핑 2
# 181 심플하게 산다
# 182 70년대생이 운다
# 183 단 한 권을 읽어도 제대로 남는 메모 독서법
# 184 지금까지 산 것처럼 앞으로도 살 건가요?
# 185 왜 나는 법을 공부하는가
# 186 자존감 회복 프로젝트
# 187 나는 왜 도와달라는 말을 못할까
# 188 내 인생을 바꾼 한 권의 책
# 189 마케터의 문장
# 190 기획의 정석
# 191 심리학이 이렇게 쓸모 있을 줄이야
# 192 신의 직장은 아니지만 공기업은 가고 싶어
# 193 한 장 보고서의 정석
# 194 빨강 머리 앤이 3년 후 나에게 : Q & A a day (램스킨 리미티드 에디션)
# 195 치유
# 196 50부터는 물건은 뺄셈 마음은 덧셈
# 197 돈보다 운을 벌어라
# 198 말투 하나로 의외로 잘 되기 시작했다
# 199 몰입 Think hard!
# 200 감정의 발견
# *************  년도: 2021 월: 2  ****************
# 5 마음챙김
# 13 객관적이고 과학적인 공부법
# 14 아침이 달라지는 저녁 루틴의 힘
# 16 그렇게 말해줘서 고마워
# 27 단단한 여자
# 29 일을 잘한다는 것
# 30 타인을 읽는 말
# 32 압축 공부
# 35 불렛저널
# 39 도티의 플랜B
# 41 실행이 답이다
# 42 1페이지 꿈지도
# 47 어른의 말공부
# 53 인생도 복리가 됩니다
# 55 메타인지, 생각의 기술
# 63 하루 한 장 마음챙김
# 68 리더는 칭찬하지 않는다
# 70 하루 3줄 영어 일기
# 76 포뮬러
# 80 변화의 시작 5AM 클럽
# 84 심리학을 만나 행복해졌다 (리커버 에디션)
# 91 놓치고 싶지 않은 나의 꿈 나의 인생 1
# 93 무기가 되는 책쓰기
# 96 이런 세상에서 지혜롭게 산다는 것
# 97 대화의 품격
# 98 메이크 타임
# 104 2억 빚을 진 내게 우주님이 가르쳐준 운이 풀리는 말버릇
# 105 이번 생은 N잡러
# 107 적게 일하고 잘사는 기술
# 110 C의 유전자
# 112 트랜서핑 현실의 지배자
# 114 내일의 나를 위한 다짐
# 118 회사를 다닐 수도, 떠날 수도 없을 때
# 125 데일 카네기 자기관리론
# 129 레오나르도 다 빈치의 두뇌 사용법
# 131 야, 너두 할 수 있어
# 132 나를 몰랐기 때문이다
# 134 결국 해내는 사람들의 원칙 (리커버 에디션)
# 143 생각대로 살지 않으면 사는 대로 생각하게 된다 1
# 146 서른 넘어 찾아온 다섯 가지 기회
# 150 유머라면 유대인처럼
# 152 다시, 대화가 필요한 시간
# 157 네 안에 잠든 거인을 깨워라
# 163 2억 빚을 진 내가 뒤늦게 알게 된 소~오름 돋는 우주의 법칙
# 169 불행한 관계 걷어차기
# 170 공부 마스터 플랜
# 171 습관을 조금 바꿨을 뿐인데 잘 풀리기 시작했다
# 173 내일을 위한 내 일
# 177 세도나 마음혁명
# 178 루틴의 힘
# 179 나는 당신이 스트레스 없이 말하면 좋겠습니다
# 183 인생의 차이를 만드는 독서법 본깨적
# 186 청소력
# 187 습관을 만드는 뇌
# 188 헤어디자이너를 위한 고객과의 대화법
# 189 고수의 보고법
# 191 나는 공부하는 엄마다
# 193 젊은 리더들을 위한 철학 수업
# 195 기버1
# 196 로지컬 씽킹
# 197 굿 라이프
# 199 허브 코헨의 협상의 기술 1
# *************  년도: 2021 월: 3  ****************
# 5 유리멘탈을 위한 심리책
# 10 조금 알고 적당히 모르는 오십이 되었다
# 11 우유곽 대학을 빌려 드립니다
# 22 김미경의 리부트 (20만부 기념 리커버 에디션)
# 28 마지막 몰입 : 나를 넘어서는 힘
# 29 방구석 노트북 하나로 월급 독립 프로젝트
# 34 코딩 진로
# 37 생각을 걸러내면 행복만 남는다
# 38 관점을 디자인하라
# 41 초조하지 않게 사는 법
# 55 사랑한다면 거리를 두는 게 좋아 (특별판 리커버 에디션)
# 60 8등급 꼴찌, 수석 졸업하게 된 9가지 공부 비결
# 87 부자의 1원칙, 몸에 투자하라
# 93 영향력을 돈으로 만드는 기술
# 103 자소서 바이블
# 104 밤의 숨소리
# 108 말 좀 잘하고 싶어
# 118 사람은 무엇으로 움직이는가
# 119 확신
# 121 레이트 블루머
# 124 사장의 탄생
# 125 새로운 열정으로 시작하라
# 142 절대 배신하지 않는 공부의 기술
# 143 1페이지 공부법
# 152 행복도 배워야 합니다
# 154 쫓기지 않는 50대를 사는 법
# 155 인간관계론 (스페셜 에디션)
# 159 케이스 인 포인트
# 162 나는 꽤 괜찮은 사람입니다
# 163 사람이 운명이다
# 168 마음챙김의 인문학
# 169 폰더 씨의 위대한 하루 실천편
# 172 놓치고 싶지 않은 나의 꿈 나의 인생 2
# 177 불광불급 : 미치려면 미쳐라
# 178 실전 보고서 작성 기술 with 파워포인트, 워드, 한글
# 179 놓치고 싶지 않은 나의 꿈 나의 인생 3
# 183 200가지 고민에 대한 마법의 명언
# 187 커피 한 잔의 명상으로 10억을 번 사람들
# 189 바야흐로, 품격영업
# 190 허브 코헨의 협상의 기술 2
# 191 일본 최고의 대부호에게 배우는 돈을 부르는 말버릇
# 192 공부하기가 죽기보다 싫을 때 읽는 책
# 194 면접 바이블 The Myunjub Bible
# 195 나는 전략적으로 살 것이다
# 197 이젠, 책쓰기다
# 199 백만장자의 아주 작은 성공 습관
# *************  년도: 2021 월: 4  ****************
# 13 위대한 시크릿
# 20 생각의 각도
# 23 타이탄의 지혜들
# 26 일은 배신하지 않는다
# 29 끌리는 말투 호감 가는 말투
# 30 프로페셔널 스튜던트
# 39 의미 있는 삶을 위하여
# 40 횡설수설하지 않고 핵심만 말하는 법
# 41 당신의 생각을 정리해드립니다
# 42 탤런트 코드 (특별합본판)
# 43 운을 부르는 습관
# 46 은둔의 즐거움
# 48 유머의 마법
# 51 결혼은 신중하게 이혼은 신속하게
# 63 여기가 끝이 아니다
# 67 혼자 사는데 돈이라도 있어야지
# 77 하나를 비우니 모든 게 달라졌다
# 79 인간 욕망의 법칙
# 80 딱 1년만 계획적으로 살아보기
# 83 초집중의 힘
# 90 산으로 가지 않는 정리법
# 93 싱크 어게인
# 97 운의 속성
# 99 물러서지 않을 용기
# 100 커리어디자인
# 101 카네기 인간관계론
# 116 인생을 바꾸는 생각들
# 125 당신과 나의 아이디어
# 131 2배속으로 월급 독립
# 132 인간 관찰
# 133 소녀는 어떻게 어른이 되는가
# 141 에너지 버스
# 144 루틴의 힘 2
# 148 데일리 루틴
# 154 그래서 역사가 필요해
# 155 책읽기가 필요하지 않은 인생은 없다
# 159 프레젠테이션 코칭 북 PresenTation Coaching Book
# 166 심리학이 돈을 말하다
# 168 3개의 소원 100일의 기적
# 174 짧은 말이 무기가 된다
# 176 나는 자는 동안에도 돈을 번다
# 183 나는 디지털노마드맘으로 살기로 했다
# 184 종이 위의 기적 쓰면 이루어진다
# 185 파워블로거 핑크팬더의 블로그 글쓰기
# 188 5초의 법칙
# 197 일 잘하는 사람은 글을 잘 씁니다
# *************  년도: 2021 월: 5  ****************
# 5 무조건 팔리는 카피 단어장
# 8 똑똑하게 생존하기
# 10 눈치껏 못 배웁니다, 일센스
# 14 인간을 바꾸는 5가지 법칙
# 28 프리워커스
# 35 생각의 쓰임
# 38 나는 이제 마음 편히 살기로 했다
# 47 리더의 말 그릇
# 68 나는 아침마다 삶의 감각을 깨운다
# 76 당신은 다른 사람의 성공에 기여한 적 있는가?
# 81 오늘부터 나는 브랜드가 되기로 했다
# 89 팀장의 말투
# 93 클린 CLEAN
# 95 나폴레온 힐 부자 수업
# 97 생각하라 그리고 부자가 되어라
# 105 나는 저녁마다 삶의 방향을 잡는다
# 112 서동주의 합격 공부법
# 113 1회성 고객을 100번 방문 고객으로 만드는 비밀
# 119 오늘부터 그 자리에 의자를 두기로 했다
# 125 터지는 콘텐츠는 이렇게 만듭니다
# 127 못난 게 아니라, 조금 서툰 겁니다
# 130 핵심만 남기고 줄이는 게 체질
# 132 조인트 사고
# 135 마음챙김이 일상이 되면 달라지는 것들
# 138 아마존처럼 회의하라
# 144 운의 알고리즘
# 147 당신만을 위한 100개의 질문
# 149 THE MAGIC 매직
# 150 승리, 패배, 그리고 교훈
# 151 더 룰 (THE RULE) - 리치 편
# 160 페어 플레이 프로젝트
# 166 이왕 시작한 거 딱, 100일만 달려 볼게요
# 173 폰더 씨의 위대한 하루
# 175 행복의 선택
# 177 그렇게 심각할 필요 없어
# 178 루이스 헤이의 치유 수업
# 181 도파민형 인간
# 187 리얼리티 트랜서핑 3
# 189 어떻게 인생을 살 것인가 (특별판 양장)
# 190 요즘 것들의 사생활 : 먹고사니즘
# 194 경험의 함정
# 196 맥스웰 몰츠 성공의 법칙
# *************  년도: 2021 월: 6  ****************
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-58-82213593faff> in <module>
#      10         driver.implicitly_wait(3)
#      11         map = '#category_layout > tbody > tr:nth-child(' + str(m*2+1) + ') > td.goodsTxtInfo > p:nth-child(1) > a:nth-child(1)'
# ---> 12         title = (driver.find_element_by_css_selector(map)).text
#      13         if title not in book_titles:
#      14             print(m+1,title)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#category_layout > tbody > tr:nth-child(1) > td.goodsTxtInfo > p:nth-child(1) > a:nth-child(1)"}
#   (Session info: chrome=90.0.4430.212)

# %% [markdown]
# ### 데이터 점검

# %%
titles = pd.DataFrame(book_titles)
abstract = pd.DataFrame(book_abstract)
final_data= pd.concat([titles, abstract],axis=1)
final_data.tail(10)
# Out:
#                           0                                                  0
# 386            폰더 씨의 위대한 하루  지금의 고통은 불공평한 세상의 장난일 뿐일까?\n행복한 이는 행복하기를, 불행한 이...
# 387                  행복의 선택  완전한 행복이란 무엇인가?\n\n완전한 행복이란 괴롭지 않게 살아가는 것이다. 그런...
# 388           그렇게 심각할 필요 없어  산전수전 공중전 다 겪어 본 인생 선배 유인경 작가가 전하는,\n주변에 흔들리지 않...
# 389           루이스 헤이의 치유 수업  전 세계 5천만 독자의 삶을 바꾼 마법의 긍정 확언\n\n미국의 대표 심리치료사이자...
# 390                 도파민형 인간  잘 중독되는 사람이 더 성공한다?\n쉽게 불타오르고 쉽게 권태로워지는 사람이 더 성...
# 391             리얼리티 트랜서핑 3  당신도 운명을 조종할 수 있다! 인간의 힘은 우리가 생각하는 것 이상으로 다양하게 ...
# 392  어떻게 인생을 살 것인가 (특별판 양장)  당신을 특별하게 만드는 인생 특강\n하버드 엘리트들의 성공 노하우!\n\n미국의 명...
# 393      요즘 것들의 사생활 : 먹고사니즘  요즘 것들은 무엇을 꿈꾸고, 왜 일하며, 어떻게 먹고살고 있을까?\n나다운 일을 찾...
# 394                  경험의 함정  경험의 '이율배반성'을 냉철하게 분석한 책\n\n조지 워싱턴 미 초대 대통령의 사망...
# 395           맥스웰 몰츠 성공의 법칙  “눈을 감아라! 상상하라! 믿어라!”\n3,000만 명이 경험한 부정적인 자아 이미...

# %%
len(final_data)
# Out:
# 396

# %% [markdown]
# ### 엑셀 파일로 저장

# %%
final_data.to_csv(f'{year}년 yes24 자기계발서 수집 데이터.csv')#, encoding='cp949')
